# %% [markdown]
# <a href="https://colab.research.google.com/github/Sadnya20/Projects/blob/main/scraping_json_dat_from_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import requests

# %%
import requests

url = "https://api.thecatapi.com/v1/images/search?limit=10"
response = requests.get(url)
print(response.json())  # Returns random cat image details
# Out:
# [{'id': '4et', 'url': 'https://cdn2.thecatapi.com/images/4et.jpg', 'width': 480, 'height': 640}, {'id': '5ei', 'url': 'https://cdn2.thecatapi.com/images/5ei.gif', 'width': 499, 'height': 402}, {'id': 'anf', 'url': 'https://cdn2.thecatapi.com/images/anf.jpg', 'width': 640, 'height': 511}, {'id': 'blo', 'url': 'https://cdn2.thecatapi.com/images/blo.jpg', 'width': 2448, 'height': 3264}, {'id': 'c4e', 'url': 'https://cdn2.thecatapi.com/images/c4e.jpg', 'width': 900, 'height': 900}, {'id': 'cvc', 'url': 'https://cdn2.thecatapi.com/images/cvc.jpg', 'width': 800, 'height': 600}, {'id': 'dhg', 'url': 'https://cdn2.thecatapi.com/images/dhg.jpg', 'width': 720, 'height': 449}, {'id': 'duk', 'url': 'https://cdn2.thecatapi.com/images/duk.png', 'width': 480, 'height': 640}, {'id': 'MjAzMTMwNw', 'url': 'https://cdn2.thecatapi.com/images/MjAzMTMwNw.jpg', 'width': 1936, 'height': 2592}, {'id': 'b6Co9acGP', 'url': 'https://cdn2.thecatapi.com/images/b6Co9acGP.jpg', 'width': 800, 'height': 450}]

# %%
df=pd.DataFrame(response.json())

# %%
print(df.shape)
# Out:
# (10, 4)

# %%
df
# Out:
#            id                                               url  width  height
# 0         4et         https://cdn2.thecatapi.com/images/4et.jpg    480     640
# 1         5ei         https://cdn2.thecatapi.com/images/5ei.gif    499     402
# 2         anf         https://cdn2.thecatapi.com/images/anf.jpg    640     511
# 3         blo         https://cdn2.thecatapi.com/images/blo.jpg   2448    3264
# 4         c4e         https://cdn2.thecatapi.com/images/c4e.jpg    900     900
# 5         cvc         https://cdn2.thecatapi.com/images/cvc.jpg    800     600
# 6         dhg         https://cdn2.thecatapi.com/images/dhg.jpg    720     449
# 7         duk         https://cdn2.thecatapi.com/images/duk.png    480     640
# 8  MjAzMTMwNw  https://cdn2.thecatapi.com/images/MjAzMTMwNw.jpg   1936    2592
# 9   b6Co9acGP   https://cdn2.thecatapi.com/images/b6Co9acGP.jpg    800     450
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['width'].plot(kind='hist', bins=20, title='width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['height'].plot(kind='hist', bins=20, title='height')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='width', y='height', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['width'].plot(kind='line', figsize=(8, 4), title='width')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['height'].plot(kind='line', figsize=(8, 4), title='height')
# plt.gca().spines[['top', 'right']].set_visible(False)
