# %%
import   requests
import pandas as pd 
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.flipkart.com/mens-footwear/~casual-and-sports-shoes/pr?sid=osp%2Ccil&p%5B%5D=facets.brand%255B%255D%3DCAMPUS&p%5B%5D=facets.brand%255B%255D%3DPUMA&p%5B%5D=facets.brand%255B%255D%3DFILA&p%5B%5D=facets.brand%255B%255D%3DHRX%2Bby%2BHrithik%2BRoshan&p%5B%5D=facets.brand%255B%255D%3DSLAZENGER&p%5B%5D=facets.brand%255B%255D%3DYONEX&p%5B%5D=facets.brand%255B%255D%3DWROGN%2BACTIVE&p%5B%5D=facets.brand%255B%255D%3DLOTTO&p%5B%5D=facets.brand%255B%255D%3DLANCER&p%5B%5D=facets.brand%255B%255D%3DJQR&p%5B%5D=facets.brand%255B%255D%3DREEBOK&p%5B%5D=facets.brand%255B%255D%3DADIDAS&p%5B%5D=facets.brand%255B%255D%3DAirson&p%5B%5D=facets.brand%255B%255D%3DPOWER&p%5B%5D=facets.brand%255B%255D%3Dasian&p%5B%5D=facets.discount_range_v1%255B%255D%3D60%2525%2Bor%2Bmore&hpid=PW42Gh968MXZA3aOHBjhm6p7_Hsxr70nj65vMAAFKlc%3D&ctx=...")

# %%
web.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [raw]
# sizes = i.find("div", class_="_0oqnJX").text.strip() if i.find("div", class_="_0oqnJX") else "N/A"

# %%
url="https://www.flipkart.com/mens-footwear/~casual-and-sports-shoes/pr?sid=osp%2Ccil&p%5B%5D=facets.brand%255B%255D%3DCAMPUS&p%5B%5D=facets.brand%255B%255D%3DPUMA&p%5B%5D=facets.brand%255B%255D%3DFILA&p%5B%5D=facets.brand%255B%255D%3DHRX%2Bby%2BHrithik%2BRoshan&p%5B%5D=facets.brand%255B%255D%3DSLAZENGER&p%5B%5D=facets.brand%255B%255D%3DYONEX&p%5B%5D=facets.brand%255B%255D%3DWROGN%2BACTIVE&p%5B%5D=facets.brand%255B%255D%3DLOTTO&p%5B%5D=facets.brand%255B%255D%3DLANCER&p%5B%5D=facets.brand%255B%255D%3DJQR&p%5B%5D=facets.brand%255B%255D%3DREEBOK&p%5B%5D=facets.brand%255B%255D%3DADIDAS&p%5B%5D=facets.brand%255B%255D%3DAirson&p%5B%5D=facets.brand%255B%255D%3DPOWER&p%5B%5D=facets.brand%255B%255D%3Dasian&p%5B%5D=facets.discount_range_v1%255B%255D%3D60%2525%2Bor%2Bmore&hpid=PW42Gh968MXZA3aOHBjhm6p7_Hsxr70nj65vMAAFKlc%3D&ctx=...&page={}"
data=[]
for  j in range (1,2):
    web=requests.get(url.format(j))
    soup=BeautifulSoup(web.content,"html.parser")
    all_info=soup.find_all("div",class_="_1sdMkc LFEi7Z")
    for i  in all_info:
        title = i.find("div", class_="syl9yP").text.strip()
        price = i.find("div", class_="Nx9bqj").text.strip() if i.find("div", class_="Nx9bqj") else "N/A"
        discount = i.find("div",class_="UkUFwK").text
        data.append({
        "Title": title,
        "Price": price,
        "Discount": discount})

# %%
data
# Out:
# [{'Title': 'HRX by Hrithik Roshan', 'Price': '₹854', 'Discount': '81% off'},
#  {'Title': 'HRX by Hrithik Roshan', 'Price': '₹740', 'Discount': '81% off'},
#  {'Title': 'CAMPUS', 'Price': '₹514', 'Discount': '65% off'},
#  {'Title': 'HRX by Hrithik Roshan', 'Price': '₹1,391', 'Discount': '72% off'},
#  {'Title': 'KILLER', 'Price': '₹899', 'Discount': '82% off'},
#  {'Title': 'HRX by Hrithik Roshan', 'Price': '₹1,079', 'Discount': '70% off'},
#  {'Title': 'HRX by Hrithik Roshan', 'Price': '₹1,159', 'Discount': '60% off'},
#  {'Title': 'asian', 'Price': '₹296', 'Discount': '62% off'},
#  {'Title': 'PUMA', 'Price': '₹1,327', 'Discount': '66% off'},
#  {'Title': 'PUMA', 'Price': '₹1,250', 'Discount': '68% off'},
#  {'Title': 'HRX by Hrithik Roshan', 'Price': '₹1,507', 'Discount': '71% off'},
#  {'Title': 'COLUMBUS', 'Price': '₹1,799', 'Discount': '60% off'},
#  {'Title': 'PUMA', 'Price': '₹1,399', 'Discount': '65% off'},
#  {'Title': 'PUMA', 'Price': '₹1,327', 'Discount': '66% off'},
# ...

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#                    Title   Price Discount
# 0  HRX by Hrithik Roshan    ₹854  81% off
# 1  HRX by Hrithik Roshan    ₹740  81% off
# 2                 CAMPUS    ₹514  65% off
# 3  HRX by Hrithik Roshan  ₹1,391  72% off
# 4                 KILLER    ₹899  82% off

# %%
df.to_csv("flipkart_shoes.csv", index=False)
